# %%
#Importar as bibliotecas
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Criar um conjunto de dados simples
dados = {
    "Ano": [2019, 2020, 2021, 2022, 2023],
    "Vendas": [150, 180, 210, 240, 300]
}

df = pd.DataFrame(dados)
df
# Out:
#     Ano  Vendas
# 0  2019     150
# 1  2020     180
# 2  2021     210
# 3  2022     240
# 4  2023     300

# %%
#Criar um gráfico
plt.figure(figsize=(8,5))
plt.plot(df["Ano"], df["Vendas"], marker="o")
plt.title("Vendas por Ano")
plt.xlabel("Ano")
plt.ylabel("Vendas")
plt.grid(True)
plt.show()
